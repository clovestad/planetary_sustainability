# %%
import pandas as pd
df = pd.read_csv("Data/fictional_planets_dataset.csv")

# %%
df.head()
# Out:
#   Solar System   Planet  Distance (light-years)  \
# 0      System1  Planet1                  590.43
# 1      System1  Planet2                   24.40
# 2      System1  Planet3                  919.78
# 3      System2  Planet1                 1066.38
# 4      System2  Planet2                  373.54
#
#    Travel Time at Speed of Light (years)  Atmospheric Oxygen Content  \
# 0                                 590.43                        0.24
# 1                                  24.40                        0.17
# 2                                 919.78                        0.15
# 3                                1066.38                        0.13
# 4                                 373.54                        0.13
#
#    Soil Fertility  Median Seasonal Temperatures (F)  \
# 0            0.73                             63.52
# 1            0.67                            -12.72
# 2            0.33                             89.49
# ...

# %%
df.describe()
# Out:
#        Distance (light-years)  Travel Time at Speed of Light (years)  \
# count             3000.000000                            3000.000000
# mean               748.079170                             748.079170
# std                435.761909                             435.761909
# min                  1.010000                               1.010000
# 25%                368.945000                             368.945000
# 50%                755.425000                             755.425000
# 75%               1118.687500                            1118.687500
# max               1499.020000                            1499.020000
#
#        Atmospheric Oxygen Content  Soil Fertility  \
# count                 3000.000000     3000.000000
# mean                     0.202050        0.551793
# std                      0.057643        0.143772
# min                      0.100000        0.300000
# 25%                      0.150000        0.430000
# ...
